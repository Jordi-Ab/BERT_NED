# %% [markdown]
# In this Script I build the "teacher" observations.
#
# I will make use of an LLM, in this case `stabilityai/StableBeluga-7B` in order to get the labels that I will be using during the training phase of our lightweight BERT model.

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
import json
from time import time
from sentence_transformers import SentenceTransformer
import nltk
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from copy import deepcopy
import ast
# local tools
from local_tools import get_most_relevant_sentences, print_progress_bar, options_to_numerated_list

# %%
print("Available devices ", torch.cuda.device_count())
for i in range(torch.cuda.device_count()):
    print(f'Device {i}:', torch.cuda.get_device_name(i))
# Out:
# Available devices  1
# Device 0: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Load Stable Beluge to the GPU

# %%
tokenizer = AutoTokenizer.from_pretrained(
    "stabilityai/StableBeluga-7B", 
    use_fast=True
)
model = AutoModelForCausalLM.from_pretrained(
    "stabilityai/StableBeluga-7B", 
    torch_dtype=torch.bfloat16,
    #low_cpu_mem_usage=True, 
    #device_map="auto"
)#.to("cuda")
model = model.to('cuda:0')
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# We will be using this embedding model in order to shorten the news article when prompt is very long
embedding_model = SentenceTransformer("all-MiniLM-L6-v2").to('cuda:0')

# %%
SYS_PROMPT = "### System:\nYou are StableBeluga, an AI that follows instructions extremely well. Help as much as you can. Remember, be safe, and don't do anything illegal.\n\n"

# %%
# Query string that will be used to ask questions to Stable Beluga
Q = """
Given this news article:

"{news_text}"

When the article mentions "{entity}", which of the following options is the news article most likely referring to? Provide only one option.
options:

{search_options}
"""

# %%
# function to make the complete prompt that will be sent to Stable Beluga
make_prompt = lambda message: "{sys_prompt}### User: {message}\n\n### Assistant:\n The news article is most likely referring to: ".format(
    sys_prompt=SYS_PROMPT,
    message=message
)

def find_answer(sb_response):
    assis_token = "### Assistant:\n "
    end_of_answer = "</s>"
    soa_ix = sb_response.find(assis_token)
    eoa_ix = sb_response.find(end_of_answer)
    sb_answer = sb_response[soa_ix+len(assis_token):eoa_ix]
    return sb_answer

def make_tokenized_prompt(article_text, entity, search_options, top_n_perc=0.6):
    if top_n_perc < 0.1:
        return None
    question = Q.format(
        news_text = article_text,
        entity = entity,
        search_options=search_options
    )
    prompt=make_prompt(question)
    inputs = tokenizer(prompt, return_tensors="pt")["input_ids"]
    tokens_length = len(inputs[0])
    if tokens_length <= 4096:
        return inputs
    else:
        #print("token lengths were greater than 4096, summarizing the most relevant sentences")
        # summarize only the most importante sentences of the article
        most_relevant_pieces = get_most_relevant_sentences(
            article_text, 
            embedding_model, 
            top_n_perc = top_n_perc
        )
        return make_tokenized_prompt(
            article_text=most_relevant_pieces, 
            entity=entity, 
            search_options=search_options,
            top_n_perc=top_n_perc-0.2
        )

def ask_sb(input_tokens):
    if input_tokens is None:
        return ""
    inputs = input_tokens.to("cuda:0")
    with torch.no_grad():
        output = model.generate(
            inputs, 
            do_sample=False, 
            #top_p=0.95, 
            #top_k=0, 
            max_new_tokens=300
        )
    response = tokenizer.decode(output[0], skip_special_tokens=False)
    answer = find_answer(response)
    return answer

# %% [markdown]
# ## Load DataSets
# `ners_extracted_sofar.json` is a 2 GB file which will not be uploaded to github.
# Contains 2,953,563 Named Entities for a subset of 112,522 news articles.
# I extracted Entities using Stanford Core NLP Python client. I focused only on PERSON, ORGANIZATION, COUNTRY and LOCATION entities.
#
# For each entity of interesIwe performed a query string search to Wikidata knowledge graph, which sometimes returned several results for each entit.
#
#
# Columns:
#
#  - `text`: Is the text of the Named Entity. For example, Donald Trump.
#  - `ner`: Is the type of the Named Entity, such as PERSON, LOCATION, etc.
#  - `nerConfidences`: Confidence of the Named Entity belonging to a NER.
#  - `clean_text`: Is the text of the Named Entity cleaned regarding special caracters and upper cased.
#  - `h1`: Is the title of the news articles. Is used as key to merge with the news articles information.
#  - `wikidata_search_entries`: Is a list of all instances of an entity that were found in Wikidata. Only one of those instances corresponds to the correct option.
#
#
# `news_with_metadata.json` is a 1.5 GB file which will not be uploaded to github.
# Contains 117,786 spanish news articles and metadata associated to those news articles, which was also extracted using other NLP techniques, such as translations and summarizations. Data was scrapped from "El Universal" digital news paper.
#
# Relevant Columns:
#  - `h1`: Is the title of the news articles. Is used as key to merge with the news articles information.
#  - `date`: Date and time when the news articles was published.
#  - `author`: Name of the author who published the article.
#  - `content`: Article text in spanish.
#  - `h1_en`: Article title translated to english.
#  - `content_en`Article text translated to English.

# %%
path_file = 'datasets/ners_extracted_sofar.json'
with open(path_file, 'r') as jfile:
    ners_data = json.load(jfile)

# %%
ners_df = pd.DataFrame.from_dict(ners_data)

# %%
# free memory
try:
    # delete variable
    del ners_data
except NameError:
    # variable has already been deleted
    pass

# %%
ners_df.shape
# Out:
# (2953563, 6)

# %%
# 'h1' if the title of the news article
len(ners_df['h1'].unique())
# Out:
# 112522

# %%
ners_df.head(20)
# Out:
#                                                  text                ner  \
# 0                                            American        NATIONALITY
# 1                                         Caleb Plant             PERSON
# 2                                               owner              TITLE
# 3                     International Boxing Federation       ORGANIZATION
# 4                                               three             NUMBER
# 5                                              Canelo             PERSON
# 6                                            Mexicans               MISC
# 7                                          strategist              TITLE
# 8                                       Justin Gamber             PERSON
# 9                                             Mexican        NATIONALITY
# 10                          next Saturday, November 6               DATE
# 11                                          MGM Grand           LOCATION
# 12                                          Las Vegas               CITY
# 13                                             Nevada  STATE_OR_PROVINCE
# 14  Complaints Commission of the National Electora...       ORGANIZATION
# 15                                                One             NUMBER
# 16                             Gabriela Jiménez Godoy             PERSON
# 17                                     representative              TITLE
# 18                           Que seguir la Democracia               MISC
# 19                                         December 9               DATE
#
#                         nerConfidences  \
# 0           {'MISC': 0.94065111011726}
# 1           {'PERSON': 0.697600692564}
# 2                                  NaN
# 3   {'ORGANIZATION': 0.89281201154313}
# 4                       {'NUMBER': -1}
# 5         {'PERSON': 0.90461856292689}
# 6           {'MISC': 0.99871178240681}
# 7                                  NaN
# 8          {'PERSON': 0.9997918079006}
# 9           {'MISC': 0.99998711367514}
# 10                        {'DATE': -1}
# 11      {'LOCATION': 0.48660150460337}
# 12      {'LOCATION': 0.99967540705336}
# 13      {'LOCATION': 0.99937623866344}
# 14  {'ORGANIZATION': 0.88405015494064}
# 15                      {'NUMBER': -1}
# 16        {'PERSON': 0.99955706357462}
# 17                                 NaN
# 18          {'MISC': 0.99983312404715}
# 19          {'DATE': 0.85690229129778}
#
#                                            clean_text  \
# 0                                            AMERICAN
# 1                                         CALEB PLANT
# 2                                               OWNER
# 3                     INTERNATIONAL BOXING FEDERATION
# 4                                               THREE
# 5                                              CANELO
# 6                                            MEXICANS
# 7                                          STRATEGIST
# 8                                       JUSTIN GAMBER
# 9                                             MEXICAN
# 10                           NEXT SATURDAY , NOVEMBER
# 11                                          MGM GRAND
# 12                                          LAS VEGAS
# 13                                             NEVADA
# 14  COMPLAINTS COMMISSION OF THE NATIONAL ELECTORA...
# 15                                                ONE
# 16                             GABRIELA JIMENEZ GODOY
# 17                                     REPRESENTATIVE
# 18                           QUE SEGUIR LA DEMOCRACIA
# 19                                           DECEMBER
#
#                                                    h1  \
# 0   A Caleb Plant no le desagrada ser visto como u...
# 1   A Caleb Plant no le desagrada ser visto como u...
# 2   A Caleb Plant no le desagrada ser visto como u...
# 3   A Caleb Plant no le desagrada ser visto como u...
# 4   A Caleb Plant no le desagrada ser visto como u...
# 5   A Caleb Plant no le desagrada ser visto como u...
# 6   A Caleb Plant no le desagrada ser visto como u...
# 7   A Caleb Plant no le desagrada ser visto como u...
# 8   A Caleb Plant no le desagrada ser visto como u...
# 9   A Caleb Plant no le desagrada ser visto como u...
# 10  A Caleb Plant no le desagrada ser visto como u...
# 11  A Caleb Plant no le desagrada ser visto como u...
# 12  A Caleb Plant no le desagrada ser visto como u...
# 13  A Caleb Plant no le desagrada ser visto como u...
# 14  INE pide inhabilitar a recolectores de firmas ...
# 15  INE pide inhabilitar a recolectores de firmas ...
# 16  INE pide inhabilitar a recolectores de firmas ...
# 17  INE pide inhabilitar a recolectores de firmas ...
# 18  INE pide inhabilitar a recolectores de firmas ...
# 19  INE pide inhabilitar a recolectores de firmas ...
#
#                               wikidata_search_entries
# 0                                                  []
# 1   [{'id': 'Q41500289', 'display_label': 'Caleb P...
# 2                                                  []
# 3   [{'id': 'Q742944', 'display_label': 'Internati...
# 4                                                  []
# 5   [{'id': 'Q37195125', 'display_label': 'Canelo'...
# 6                                                  []
# 7                                                  []
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11  [{'id': 'Q713960', 'display_label': 'MGM Grand...
# 12  [{'id': 'Q23768', 'display_label': 'Las Vegas'...
# 13  [{'id': 'Q1227', 'display_label': 'Nevada', 'd...
# 14                                                 []
# 15                                                 []
# 16                                                 []
# 17                                                 []
# 18                                                 []
# 19                                                 []

# %%
path_file = 'datasets/news_with_metadata.json'
with open(path_file, 'r') as jfile:
    processed_news_articles = json.load(jfile)

# %%
processed_news_articles_df = pd.DataFrame.from_dict(processed_news_articles)

# %%
processed_news_articles_df.shape
# Out:
# (117786, 18)

# %%
processed_news_articles_df.head(5)
# Out:
#                                                   h1  \
# 0  Cancelan “Noche de Rábanos” en Oaxaca por ries...
# 1  Pepenadores se casan en relleno sanitario, don...
# 2  Ladrón se mete a casa en Coyoacán de diputada ...
# 3  Automovilistas evitan atraco y tunden a golpes...
# 4  Detienen a ladrón, lo amarran a un poste y le ...
#
#                                                   h2               h3  \
# 0  A través de un video, el gobernador Alejandro ...  Más Información
# 1  Con apoyo de las autoridades de Ciudad Victori...  Más Información
# 2  La legisladora Edna Laura Huerta Ruiz dijo a l...  Más Información
# 3  Los conductores que atestiguaron un robo sobre...  Más Información
# 4  Habitantes del fraccionamiento Villas del Pedr...  Más Información
#
#                date                            author  \
# 0  23/12/2021 09:09  Fernando Miranda / Corresponsal
# 1  17/12/2019 00:02            Redacción El Universal
# 2  29/03/2021 14:41                        Redacción
# 3  15/09/2021 09:31            Redacción El Universal
# 4  30/09/2021 16:01                        Redacción
#
#                                              content  \
# 0  .– Ante el  aumento de casos de Covid-19 y en ...
# 1  Jesús Gallegos y Juana Martínez se conocieron ...
# 2  La diputada federal por Morena, Edna Laura Hue...
# 3  Tras asaltar a punta de pistola  a tres automo...
# 4  Morelia.- Vecinos del  fraccionamiento Villas ...
#
#                                                h1_en  \
# 0  “Night of Radishes” Canceled in Oaxaca by Risk...
# 1  Pepenadores get married in sanitary filling, w...
# 2  Thief enters home in Coyoacán as federal deput...
# 3  Motorists avoid robbery and beat up thief in I...
# 4  They arrest a thief, tie him to a pole, and wh...
#
#                                                h2_en  \
# 0  Through a video, Governor Alejandro Murat repo...
# 1  With the support of the authorities of Ciudad ...
# 2  Legislator Edna Laura Huerta Ruiz told the aut...
# 3  The drivers who testified to a robbery over th...
# 4  Residents of the Villas del Pedregal division ...
#
#                                           content_en  content_len  \
# 0  .– In view of the increase in Covid-19 cases a...          NaN
# 1  Jesús Gallegos and Juana Martínez met five yea...          NaN
# 2  The federal deputy for Morena, Edna Laura Huer...          NaN
# 3  After assaulting three motorists at gunpoint, ...          NaN
# 4  Morelia.- Neighbors of the Villas del Pedregal...          NaN
#
#                                              summary  \
# 0  The government of Oaxaca cancelled the traditi...
# 1  Jesús Gallegos and Juana Martínez met five yea...
# 2  Federal deputy Edna Laura Huerta Ruiz was a vi...
# 3  A repeat thief who assaulted three motorists a...
# 4  Neighbors of the Villas del Pedregal division ...
#
#    article_summary_similarity  \
# 0                    0.834634
# 1                    0.769818
# 2                    0.718933
# 3                    0.819494
# 4                    0.779302
#
#                                 content_en_embedding  Topic  \
# 0  [-0.0039373683, 0.1377171576, 0.0249814242, 0....   1193
# 1  [-0.0183615051, 0.0783702508, 0.0043704007, 0....   2702
# 2  [-0.0195583869, 0.0726484135, -0.0551280603, -...   3528
# 3  [-0.0368850492, 0.1118888482, 0.0172117595, 0....    937
# 4  [-0.0057766289, 0.0313035548, -0.0007194448, -...   3735
#
#                                             entities  \
# 0  [Oaxaca government, Governor Alejandro Murat, ...
# 1  [Jesús Gallegos, Juana Martínez, Ciudad Victor...
# 2  [Federal deputy for Morena, Edna Laura Huerta ...
# 3  [Repeat thief, Motorists, Ignacio Zaragoza Cau...
# 4  [Villas del Pedregal division of Morelia, Mich...
#
#                                            keypoints  \
# 0  [Cancellation of "Night of Rábanos" due to Cov...
# 1  [Landfill couple's wedding in Ciudad Victoria,...
# 2  [Federal deputy for Morena, Edna Laura Huerta ...
# 3  [Repeat thief assaults three motorists at gunp...
# 4  [Neighbors arrest a man stealing inside a hous...
#
#                                          main_entity  \
# 0                                             Oaxaca
# 1                  Jesús Gallegos and Juana Martínez
# 2                             Edna Laura Huerta Ruiz
# 3  The main entity mentioned in the news article ...
# 4  The main entity mentioned in the news article ...
#
#   sentiment_towards_main_entity
# 0                      NEGATIVE
# 1                      POSITIVE
# 2                      NEGATIVE
# 3                      NEGATIVE
# 4                      NEGATIVE

# %%
# free memory
try:
    # delete variable
    del processed_news_articles
except NameError:
    # variable has already been deleted
    pass

# %%
# temporary file that will hold checkopoints in case that the process breaks.
path_file = 'ask_sb_sofar.json'
try:
    # open the checkpoint
    with open(path_file, 'r') as jfile:
        asked_sb_sofar = json.load(jfile)
    already_asked_sb = pd.DataFrame.from_dict(asked_sb_sofar)
    # index to identify where the process stopped, becomes entity + title
    already_asked_sb['ix'] = already_asked_sb['text']+'-'+already_asked_sb['h1']
except FileNotFoundError:
    # no checkpoint has been saved so far, process will start from the beginning
    asked_sb_sofar = []

# %%
ners_df['ix'] = ners_df['text']+'-'+ners_df['h1']

# %%
if len(asked_sb_sofar) > 0:
    to_ask_sb = ners_df[
        (ners_df['wikidata_search_entries'].apply(len) >1 )&
        ~(ners_df['ix'].isin(already_asked_sb['ix']))
    ]
else:
    to_ask_sb = ners_df[
        (ners_df['wikidata_search_entries'].apply(len) >1 )
    ]

# %%
to_ask_sb.head(5)
# Out:
#                                text           ner  \
# 1                       Caleb Plant        PERSON
# 3   International Boxing Federation  ORGANIZATION
# 5                            Canelo        PERSON
# 11                        MGM Grand      LOCATION
# 12                        Las Vegas          CITY
#
#                         nerConfidences                       clean_text  \
# 1           {'PERSON': 0.697600692564}                      CALEB PLANT
# 3   {'ORGANIZATION': 0.89281201154313}  INTERNATIONAL BOXING FEDERATION
# 5         {'PERSON': 0.90461856292689}                           CANELO
# 11      {'LOCATION': 0.48660150460337}                        MGM GRAND
# 12      {'LOCATION': 0.99967540705336}                        LAS VEGAS
#
#                                                    h1  \
# 1   A Caleb Plant no le desagrada ser visto como u...
# 3   A Caleb Plant no le desagrada ser visto como u...
# 5   A Caleb Plant no le desagrada ser visto como u...
# 11  A Caleb Plant no le desagrada ser visto como u...
# 12  A Caleb Plant no le desagrada ser visto como u...
#
#                               wikidata_search_entries  \
# 1   [{'id': 'Q41500289', 'display_label': 'Caleb P...
# 3   [{'id': 'Q742944', 'display_label': 'Internati...
# 5   [{'id': 'Q37195125', 'display_label': 'Canelo'...
# 11  [{'id': 'Q713960', 'display_label': 'MGM Grand...
# 12  [{'id': 'Q23768', 'display_label': 'Las Vegas'...
#
#                                                    ix
# 1   Caleb Plant-A Caleb Plant no le desagrada ser ...
# 3   International Boxing Federation-A Caleb Plant ...
# 5   Canelo-A Caleb Plant no le desagrada ser visto...
# 11  MGM Grand-A Caleb Plant no le desagrada ser vi...
# 12  Las Vegas-A Caleb Plant no le desagrada ser vi...

# %%
# free memory
try:
    # delete variable
    del ners_df
except NameError:
    # variable has already been deleted
    pass

# %%
# Example for one entry point in the process. We will use "Andres Manuel Lopez Obrador" as en example
example = to_ask_sb[to_ask_sb['text'] == 'Andres Manuel Lopez Obrador'].iloc[0]
print(example)
# Out:
# text                                             Andres Manuel Lopez Obrador
# ner                                                                   PERSON
# nerConfidences                                       {'PERSON': 0.998525444}
# clean_text                                       ANDRES MANUEL LOPEZ OBRADOR
# h1                         Anuncia Monreal su participación en "legítima"...
# wikidata_search_entries    [{'id': 'Q318508', 'display_label': 'Andrés Ma...
# ix                         Andres Manuel Lopez Obrador-Anuncia Monreal su...
# Name: 2140677, dtype: object

# %%
title = example['h1']
entity = example['text']
text = processed_news_articles_df[
    processed_news_articles_df['h1'] == title
]['content_en'].iloc[0]
options = options_to_numerated_list(
    [
        i.get("label_desc") for i in example['wikidata_search_entries']
    ]
)
sb_question_tokens = make_tokenized_prompt(
    article_text=text, 
    entity=entity, 
    search_options=options, 
    top_n_perc=0.6
)
question = Q.format(
    news_text = text,
    entity = entity,
    search_options=options
)
print("Stable Beluga Query: \n{0}".format(question))
sb_answer = ask_sb(sb_question_tokens)
print("Stable Beluga Disambiguation answer: \n{0}".format(sb_answer))
# Out:
# Stable Beluga Query:
#
# Given this news article:
#
# "President Andres Manuel Lopez Obrador's call for the next scheduled on 27 November for the Angel of Independence to the Zócalo is legitimate, said Morena's leader in the Senate, Ricardo Monreal Ávila, who announced that he will participate in that mobilization, because he is part of the Movement that won the Presidency of the Republic in 2018. In an interview, the legislator said that the president is in all his right to march in the streets as he did many times as an opposition leader. “He believes that this must be the case and we must respect him, not forgetting that he is head of state, the President is President of all Mexicans and of all Mexicans, including opponents, because the rules of democracy are so and so they must be observed. When López Obrador was elected in 2018 he won democratically,” he said. Monreal Ávila said that he is going to march with President López Obrador, although he acknowledged that he could suffer a disappointment on the part of the president, but considered that “these are the risks of democracy.” Also read: When AMLO installed a sit-in in Reforma and said he avoided a tragedy “I am a supporter of him, I am a member of the Movement he led. I am a builder of the Movement that won the election in 2018 and of course I will be there on time, with solidarity and respect for all kinds of expressions,” he remarked. “At least, the senators of Morena, I think that for the most part, we will accompany him modestly, in a subtle accompaniment, without any protagonism, because it is simply to express our solidarity and our conviction that what we did in 18 we continue to support him,” he said. Senator Monreal commented that he does not remember a Mexican president, Head of State, who has led such a march, “because obviously it will be massive, I assure you. Not 300 or 400 (thousand), I think it will be a march of millions, because besides now Morena governs states that never did.” Finally, he hoped that there would be no use of public resources in this march and that it would be neither a reason for further polarization of society. Also read: Who was the last president to march in your government as AMLO? With information from Luis Carlos Rodríguez Subscribe here to receive directly in your mail our newsletters about news of the day, opinion, Qatar 2022 and many more options. rmlgv"
#
# When the article mentions "Andres Manuel Lopez Obrador", which of the following options is the news article most likely referring to? Provide only one option.
# options:
#
# 1. Andrés Manuel López Obrador, President of Mexico since 2018
# 2. Andrés Manuel López Obrador gana la Presidencia de México, Wikinews article
# 3. Andrés Manuel López Obrador llama a una movilización contra la reforma energética, Wikinews article
# 4. Andrés Manuel López Obrador contenderá por la presidencia de México en 2012, Wikinews article
#
#
# Stable Beluga Disambiguation answer:
# The news article is most likely referring to:
#
# 1. Andrés Manuel López Obrador, President of Mexico since 2018

# %% [markdown]
# ## Trigger the Process
#
# Now we run the above process for the whole 2,953,563 Named Entities on a subset of 112,522 news articles on a loop. This way, Stable Belgua will help us create a big dataset of disambiguated observations which we can later use to fine tune a BERT model. The objective of fine tuning BERT is to have a lightweight model that can dismabiguate as good as Stable Belgua 7B.
#
# The whole Stable Belgua disambiguation process took around 1 week on my 4090 GPU.
#
# A lightweight model, as we will later see, uses 3x less GPU memory (which translates to lower GPU prouctive costs) and performs the disambiguation 3x faster (which also translates in faster productive systems).

# %%
sb_results = asked_sb_sofar
total_entries = len(to_ask_sb.to_dict(orient='records'))
for i, entry in enumerate(to_ask_sb.to_dict(orient='records')):
    if i%1000 == 0:
        torch.cuda.empty_cache()
        
    new_entry = deepcopy(entry)
    title = entry['h1']
    entity = entry['text']
    text = processed_news_articles_df[
        processed_news_articles_df['h1'] == title
    ]['content_en'].iloc[0]
    options = options_to_numerated_list(
        [
            i.get("label_desc") for i in entry['wikidata_search_entries']
        ]
    )
    sb_question_tokens = make_tokenized_prompt(
        article_text=text, 
        entity=entity, 
        search_options=options, 
        top_n_perc=0.6
    )
    sb_answer = ask_sb(sb_question_tokens)
    new_entry['sb_answer'] = sb_answer
    new_entry['options_given'] = options
    sb_results.append(new_entry)

    if i%1000 == 0:
        print_progress_bar(
            iteration=i, 
            total=total_entries, 
            bar_length=50
        )
        with open("ask_sb_sofar.json", "w") as file:
            json.dump(sb_results, file)

with open("datasets/sb_disambiguation_result.json", "w") as file:
    json.dump(sb_results, file)
# Out:
# Progress: [================================================= ] 100%
