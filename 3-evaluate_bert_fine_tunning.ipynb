# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification
import numpy as np
import pandas as pd
import json
import re
import nltk
import string

def create_regex_pattern(term):
    # function that creates a regex pattern with word boundaries
    return r'\b' + re.escape(term) + r'\b'

def get_sentences_containing_entity(row):
    content = row['content_en']
    ent = row['text']
    sents_srs = pd.Series(nltk.sent_tokenize(content))
    reg = create_regex_pattern(ent)
    sents_containing_ent = sents_srs[
        sents_srs.str.contains(reg, regex=True)
    ].tolist()
    return sents_containing_ent

def print_progress_bar(iteration, total, bar_length=50):
    progress = float(iteration) / float(total)
    arrow = '=' * int(round(progress * bar_length) - 1)
    spaces = ' ' * (bar_length - len(arrow))

    print(f'Progress: [{arrow + spaces}] {int(progress * 100)}%', end='\r')

def build_query_for_bert_ned(
    entity_text, sentence_mention, option
):
    query = " Is '{entity_mention}' in the context of: '{sentence_mention}', referring to [SEP] {option}?".format(
        entity_mention=entity_text,
        sentence_mention=sentence_mention,
        option=option
    )
    return query

def join_text_tokens(tokens):
    text = ''.join(
        [
            tokens[i] if tokens[i] in string.punctuation else ' ' + tokens[i] for i in range(len(tokens))
        ]
    ).strip()
    return text

def find_surrounding_text(target_word, sentence, n_tokens=5):
    
    start_indices = [
        m.start() for m in re.finditer(
            r'\b' + re.escape(target_word) + r'\b', 
            sentence, 
            flags=re.IGNORECASE)
    ]
    
    surrounding_words = []
    for ix in start_indices:
        before_txt = sentence[:ix]
        before_tkns = nltk.word_tokenize(before_txt)
        before_n_tokens = before_tkns[-n_tokens:]
        after_txt = sentence[ix+len(target_word):]
        after_tkns = nltk.word_tokenize(after_txt)
        after_n_tokens = after_tkns[:n_tokens]
        all_tokens = before_n_tokens + [target_word] + after_n_tokens 
        surrounding_txt = join_text_tokens(all_tokens)
        surrounding_words.append(surrounding_txt)
    return surrounding_words

class BertNED():
    
    def __init__(self):
        # predictions will be made on the gpu if there is a gpu available
        self.device = torch.device(
            "cuda:0" if torch.cuda.is_available() else "cpu"
        )
        # load the BERT NED model
        self.model = BertForSequenceClassification.from_pretrained(
            'JordiAb/BERT_NED'
        ).eval().to(self.device)
        # load the BERT NED tokenizer
        self.tokenizer = BertTokenizer.from_pretrained(
            'JordiAb/BERT_NED'
        )
    
    def _predict_proba(self, input_ids, attention_mask):
        """
        Make a call to our BERT model in order to compute the probability of a tokenized string like:
        " Is '{entity}' in the context of: '{context}', referring to [SEP] {option}?"
        Receives:
         - input_ids: Tensor: Tokenized string
         - attention_mask: Tensor: Tokenized attention mask
        Returns:
         - np.array([prob0, prob1]): numpy array containing the two probabilities. Probability of belongin to
           class 0 and probability of belonging to class 1.
        """
        # move input ids to GPU (if available)
        iids = input_ids.to(self.device)
         # move attention mask to GPU (if available)
        att_msk = attention_mask.to(self.device)
        with torch.no_grad(): # avoid gradient computation to save memory
            # forward pass of the model
            outputs = self.model(
                input_ids=iids, 
                token_type_ids=None, 
                attention_mask=att_msk
            )
    
        # get logits of prediction
        logits = outputs.logits
        # Use softmax to get probabilities
        probabilities = torch.nn.functional.softmax(logits, dim=1)
        # is meant for one observation so return probabilities[0], move the resulting tensor to cpu and return it as numpy array
        return probabilities[0].cpu().numpy()
    
    def _compute_scores(self, entity, context, options):
        """
        Given a single entity and context where the entity is mentioned.
        For all options, encode the input as expected by our BERT model and predict the probability 
        of a single option being the correct option given the context where the entity is being mentioned.
        Receives:
         - entity: str: The entity to desambiguate.
         - context: str: Sentence or context window where the entity is being mentioned.
         - options: list: List of descriptions of the posible entities.
        Returns:
         - scores: np.array: (n_options x 2) matrix of probabilities for each option. Each option has 2 probabilities. 
           Probability of belongin to class 0 and probability of belonging to class 1.
        Example:
         entity = "Donald Trump"
         context = "A personal aide to U.S. President Donald Trump gave positive to coronavirus",
         options =  [
            'Donald Trump, president of the United States from 2017 to 2021',
            'Donald Trump, American physician',
            'Donald Trump, Wikimedia disambiguation page',
            'Donald Trump, song by Mac Miller',
            'Donald Trump, segment of an episode of Last Week Tonight',
            "Donald Trump, character Donald Trump in Anthony Davis's opera The Central Park Five",
            '2016 United States presidential election, 58th quadrennial U.S. presidential election'
         ]
         >>> compute_scores(entity, context, options)
         >>> array(
          [[9.2529238e-04, 9.9907470e-01],
           [9.9969673e-01, 3.0326008e-04],
           [9.9955863e-01, 4.4132231e-04],
           [9.9969578e-01, 3.0429140e-04],
           [9.9968457e-01, 3.1540715e-04],
           [9.9969685e-01, 3.0312332e-04],
           [9.9966502e-01, 3.3492901e-04]], 
         dtype=float32
        )
        """
        scores = []
        # For each option in the list of possible options ...
        for option in options:
            n_tokens = 30
            # we will keep looping
            while True:
                
                # build the query string required by our BERT model. Namely:
                #" Is '{entity}' in the context of: '{context}', referring to [SEP] {option}?"
                query = build_query_for_bert_ned(
                    entity, context, option
                )
                
                # encode and tokenize the query string
                encoded_dict = self.tokenizer.encode_plus(
                    query,                           # Sentence to encode.
                    add_special_tokens = True,       # Add '[CLS]' and '[SEP]'
                    #max_length = 512,                # Pad & truncate all sentences.
                    #padding='max_length',            # Make sure this applies padding as needed
                    #truncation=True,
                    return_attention_mask = True,    # Construct attention masks.
                    return_tensors = 'pt',           # Return pytorch tensors.
                )
    
                # condition required to stop the loop
                if encoded_dict['input_ids'].shape[1]<=512:
                    # tokenized query string is less than the max length expected by our BERT model
                    # we can proceed to compute the probability of this option.
                    prob = self._predict_proba(
                        input_ids=encoded_dict['input_ids'], 
                        attention_mask=encoded_dict['attention_mask']
                    )
                    # append probability of option
                    scores.append(prob)
                    # break from while True loop
                    break
                
                # condition was not met, meaning the tokenized string was longer than max length expected by our BERT model
                # we will shorten the context by getting the "n_tokens" that sorround the entity mention
                contexts = find_surrounding_text(
                    target_word=entity, 
                    sentence=context, 
                    n_tokens=n_tokens
                )
                # entity might be mentioned several times on a single sentece, just get the first mention to keep things simple
                # or "None" if for some strange reason, there is no entity mention in the sentences (which shouldn't happend if preprocessing was done correctly)
                context = 'None' if len(contexts)==0 else contexts[0]
                # decrease the number of tokens that surround the entity mention 
                n_tokens-= 5
                # keep looping ...
        return np.array(scores)
    
    def desambiguate(self, entity, contexts, options, verbose=False):
        """
        Function used to desambiguate an `entity` when there are several possible entity matches.
        Uses a BERT based model that predicts a probability of an option being the correct option
        given the context where the entity is being mentioned.
        -------------------------------
        Receives:
         - entity: str: The entity to desambiguate.
         - contexts: list: List of sentences or context windows where the entity is being mentioned.
         - options: list: List of descriptions of the posible entities.
        Returns:
         - best_option_ix: int: Index where the option with the highest probability is located in the options list
        Example:
         entity = "Donald Trump"
         contexts = [
           "A personal aide to U.S. President Donald Trump gave positive to coronavirus", 
           "It's not the first scare for Donald Trump. In early March it was announced that Brazilian President Jair Bolsonaro, gave positive to coronavirus, after participating in a meeting in Florida where the US president was."
         ]
         options = [
            'Donald Trump, president of the United States from 2017 to 2021',
            'Donald Trump, American physician',
            'Donald Trump, Wikimedia disambiguation page',
            'Donald Trump, song by Mac Miller',
            'Donald Trump, segment of an episode of Last Week Tonight',
            "Donald Trump, character Donald Trump in Anthony Davis's opera The Central Park Five",
            '2016 United States presidential election, 58th quadrennial U.S. presidential election'
        ]
        >>> desambiguate(entity, contexts, options, verbose=True)
            Entity: Donald Trump
            Options:
            	Donald Trump, president of the United States from 2017 to 2021: 0.9990746974945068
            	Donald Trump, American physician: 0.00032277879654429853
            	Donald Trump, Wikimedia disambiguation page: 0.00044132230686955154
            	Donald Trump, song by Mac Miller: 0.0003152454155497253
            	Donald Trump, segment of an episode of Last Week Tonight: 0.00031540714553557336
            	Donald Trump, character Donald Trump in Anthony Davis's opera The Central Park Five: 0.00030414783395826817
            	2016 United States presidential election, 58th quadrennial U.S. presidential election: 0.0005287989042699337
            Best option: Donald Trump, president of the United States from 2017 to 2021
            -------
        >>> 0
        """
        
        sents_scores = []
        # entity might be mentioned in several sentences (contexts)
        # for each context where entity is mentioned, compute scores of all options
        for context in contexts:
            scores = self._compute_scores(entity, context, options)
            # append probabilities of belonging to class 1 (for each option)
            sents_scores.append(scores[:,1])
        
        # matrix with n_contexts rows and n_options columns
        cont_scores_mat = np.array(sents_scores)
        # get option with better probability across all contexts
        best_options = np.max(cont_scores_mat, axis=0)
        # get index of best option
        best_option_ix = np.argmax(best_options)
    
        if verbose:
            print('Entity: {0}'.format(entity))
            print("Options:")
            for o, s in zip(options, np.max(np.array(sents_scores), axis=0)):
                print("\t{0}: {1}".format(o,s))
            print("Best option: {0}".format(options[best_option_ix]))
            print('-------')
    
        return best_option_ix

# %%
entity = "Donald Trump"
contexts = [
   "A personal aide to U.S. President Donald Trump gave positive to coronavirus", 
   "It's not the first scare for Donald Trump. In early March it was announced that Brazilian President Jair Bolsonaro, gave positive to coronavirus, after participating in a meeting in Florida where the US president was."
]
options = [
    'Donald Trump, president of the United States from 2017 to 2021',
    'Donald Trump, American physician',
    'Donald Trump, Wikimedia disambiguation page',
    'Donald Trump, song by Mac Miller',
    'Donald Trump, segment of an episode of Last Week Tonight',
    "Donald Trump, character Donald Trump in Anthony Davis's opera The Central Park Five",
    '2016 United States presidential election, 58th quadrennial U.S. presidential election'
]

# %%
bert_ned = BertNED()
# Out:
# config.json:   0%|          | 0.00/725 [00:00<?, ?B/s]
# D:\Users\jordi\venvs\bart\Lib\site-packages\huggingface_hub\file_download.py:147: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in D:\Users\jordi\.cache\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# pytorch_model.bin:   0%|          | 0.00/433M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/367 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
bert_ned.desambiguate(entity, contexts, options, verbose=True)
# Out:
# Entity: Donald Trump
# Options:
# 	Donald Trump, president of the United States from 2017 to 2021: 0.9990746974945068
# 	Donald Trump, American physician: 0.00032277879654429853
# 	Donald Trump, Wikimedia disambiguation page: 0.00044132230686955154
# 	Donald Trump, song by Mac Miller: 0.0003152454155497253
# 	Donald Trump, segment of an episode of Last Week Tonight: 0.00031540714553557336
# 	Donald Trump, character Donald Trump in Anthony Davis's opera The Central Park Five: 0.00030414783395826817
# 	2016 United States presidential election, 58th quadrennial U.S. presidential election: 0.0005287989042699337
# Best option: Donald Trump, president of the United States from 2017 to 2021
# -------
# 0

# %%
bert_ned._compute_scores(entity, contexts[0], options)
# Out:
# array([[9.2529238e-04, 9.9907470e-01],
#        [9.9969673e-01, 3.0326008e-04],
#        [9.9955863e-01, 4.4132231e-04],
#        [9.9969578e-01, 3.0429140e-04],
#        [9.9968457e-01, 3.1540715e-04],
#        [9.9969685e-01, 3.0312332e-04],
#        [9.9966502e-01, 3.3492901e-04]], dtype=float32)

# %%
with open("../extract_ners/ask_sb_sofar_val.json", "r") as file:
    data_missing_ned = json.load(file)

# %%
unobserved_df = pd.DataFrame.from_dict(data_missing_ned)

# %%
path_file = '../../news_data/news_with_metadata.json'
with open(path_file, 'r') as jfile:
    processed_news_articles = json.load(jfile)

# %%
processed_news_articles_df = pd.DataFrame.from_dict(processed_news_articles)

# %%
validation_df = pd.merge(
    unobserved_df,
    processed_news_articles_df[['h1', 'content_en']],
    how='left',
    on='h1'
)

# %%
del processed_news_articles_df
del processed_news_articles
del data_missing_ned

# %%
validation_df
# Out:
#                       text           ner                      nerConfidences  \
# 0                Zacatecas          CITY      {'LOCATION': 0.98695854325281}
# 1                 Culiacán        PERSON        {'PERSON': 0.43934991439724}
# 2      Palacio de Gobierno      LOCATION      {'LOCATION': 0.88592453954918}
# 3                    State  ORGANIZATION  {'ORGANIZATION': 0.44361875069213}
# 4                Fresnillo          CITY      {'LOCATION': 0.86880109112666}
# ...                    ...           ...                                 ...
# 51996               Mexico       COUNTRY      {'LOCATION': 0.86121711995959}
# 51997             Santiago          CITY      {'LOCATION': 0.60977913237806}
# 51998           Peña Nieto        PERSON        {'PERSON': 0.74281429426886}
# 51999                Pemex  ORGANIZATION  {'ORGANIZATION': 0.96210365359227}
# 52000               Toluca          CITY      {'LOCATION': 0.98220323937029}
#
#                 clean_text                                                 h1  \
# 0                ZACATECAS  Cenace advierte de nuevos cortes de luz “rotat...
# 1                 CULIACAN  Madres rastreadoras de Sinaloa exigen la desti...
# 2      PALACIO DE GOBIERNO  Madres rastreadoras de Sinaloa exigen la desti...
# 3                    STATE  Madres rastreadoras de Sinaloa exigen la desti...
# 4                FRESNILLO  “Ya no hagan de emoción”: Forcejean a llegada ...
# ...                    ...                                                ...
# 51996               MEXICO  Mexico’s Financial Intelligence Unit freezes 1...
# 51997             SANTIAGO  Mexico’s Financial Intelligence Unit freezes 1...
# 51998           PENA NIETO  Mexico’s Financial Intelligence Unit freezes 1...
# 51999                PEMEX  Cofece investiga, otra vez, comercialización d...
# 52000               TOLUCA  Cuestionan a Morena por abstenerse a participa...
#
#                                  wikidata_search_entries  \
# 0      [{'id': 'Q80269', 'display_label': 'Zacatecas'...
# 1      [{'id': 'Q211760', 'display_label': 'Culiacán'...
# 2      [{'id': 'Q385938', 'display_label': 'Governmen...
# 3      [{'id': 'Q7275', 'display_label': 'state', 'di...
# 4      [{'id': 'Q1816543', 'display_label': 'Fresnill...
# ...                                                  ...
# 51996  [{'id': 'Q96', 'display_label': 'Mexico', 'dis...
# 51997  [{'id': 'Q2887', 'display_label': 'Santiago', ...
# 51998  [{'id': 'Q296741', 'display_label': 'Enrique P...
# 51999  [{'id': 'Q871308', 'display_label': 'Pemex', '...
# 52000  [{'id': 'Q209034', 'display_label': 'Toluca', ...
#
#                                                       ix  \
# 0      Zacatecas-Cenace advierte de nuevos cortes de ...
# 1      Culiacán-Madres rastreadoras de Sinaloa exigen...
# 2      Palacio de Gobierno-Madres rastreadoras de Sin...
# 3      State-Madres rastreadoras de Sinaloa exigen la...
# 4      Fresnillo-“Ya no hagan de emoción”: Forcejean ...
# ...                                                  ...
# 51996  Mexico-Mexico’s Financial Intelligence Unit fr...
# 51997  Santiago-Mexico’s Financial Intelligence Unit ...
# 51998  Peña Nieto-Mexico’s Financial Intelligence Uni...
# 51999  Pemex-Cofece investiga, otra vez, comercializa...
# 52000  Toluca-Cuestionan a Morena por abstenerse a pa...
#
#                                                sb_answer  \
# 0      The news article is most likely referring to: ...
# 1      The news article is most likely referring to: ...
# 2      The news article is most likely referring to: ...
# 3      The news article is most likely referring to: ...
# 4      The news article is most likely referring to: ...
# ...                                                  ...
# 51996  The news article is most likely referring to: ...
# 51997  The news article is most likely referring to: ...
# 51998  The news article is most likely referring to: ...
# 51999  The news article is most likely referring to: ...
# 52000  The news article is most likely referring to: ...
#
#                                            options_given  \
# 0      1. Zacatecas, state of Mexico \n2. Zacatecas, ...
# 1      1. Culiacán, capital and largest city in the M...
# 2      1. Government Palace, seat of the executive br...
# 3      1. state, organised community living under a s...
# 4      1. Fresnillo, city in Fresnillo Municipality, ...
# ...                                                  ...
# 51996  1. Mexico, country in North America \n2. Mexic...
# 51997  1. Santiago, capital city of Chile \n2. St. Ja...
# 51998  1. Enrique Peña Nieto, 64th President of Mexic...
# 51999  1. Pemex, Mexican state-owned petroleum compan...
# 52000  1. Toluca, City in the capital municipality of...
#
#                                               content_en
# 0      The National Energy Control Center (Cenace) an...
# 1      Culiacán, Sin.- In the esplanade of Palacio de...
# 2      Culiacán, Sin.- In the esplanade of Palacio de...
# 3      Culiacán, Sin.- In the esplanade of Palacio de...
# 4      Fresnillo, Zacatecas.- President Andrés Manuel...
# ...                                                  ...
# 51996  Santiago Nieto, the head of the Financial Inte...
# 51997  Santiago Nieto, the head of the Financial Inte...
# 51998  Santiago Nieto, the head of the Financial Inte...
# 51999  Due to the possible existence of anti-competit...
# 52000  Toluca, Méx.- The president of the PRI's State...
#
# [52001 rows x 10 columns]

# %%
validation_df.shape
# Out:
# (52001, 10)

# %%
validation_df['label_desc_options'] = validation_df['wikidata_search_entries'].apply(
    lambda x: [i.get('label_desc') for i in x]
)

# %%
validation_df['sents_with_ent'] = validation_df.apply(lambda row: get_sentences_containing_entity(row), axis=1)

# %%
validation_df['sents_len'] = validation_df['sents_with_ent'].apply(len)

# %%
# drop observations with no sentence mentions
validation_df.drop(validation_df[validation_df['sents_len']==0].index, inplace=True)

# %%
regex_pattern = "The news article is most likely referring to:"
validation_df['sb_option_given'] = validation_df['sb_answer'].str[len(regex_pattern):]
validation_df['sb_option_given'] = validation_df['sb_option_given'].str.replace('\n', '').str.strip()

# %%
regex_pattern = r"(\d+.)(.*)"
validation_df[['index_of_option_given', 'sb_option_given']] = validation_df['sb_option_given'].str.extract(regex_pattern)
validation_df['index_of_option_given'] = validation_df['index_of_option_given'].str.replace(".", "").str.strip()
validation_df['sb_option_given'] = validation_df['sb_option_given'].str.strip()

# %%
validation_df[validation_df['index_of_option_given'].isnull()]
# Out:
# Empty DataFrame
# Columns: [text, ner, nerConfidences, clean_text, h1, wikidata_search_entries, ix, sb_answer, options_given, content_en, label_desc_options, sents_with_ent, sents_len, sb_option_given, index_of_option_given]
# Index: []

# %%
validation_df['index_of_option_given'] = (validation_df['index_of_option_given'].astype(int) - 1)

# %%
validation_df = validation_df.reset_index(drop=True).reset_index()

# %%
validation_df.head(5)
# Out:
#    index                 text           ner  \
# 0      0            Zacatecas          CITY
# 1      1             Culiacán        PERSON
# 2      2  Palacio de Gobierno      LOCATION
# 3      3                State  ORGANIZATION
# 4      4            Fresnillo          CITY
#
#                        nerConfidences           clean_text  \
# 0      {'LOCATION': 0.98695854325281}            ZACATECAS
# 1        {'PERSON': 0.43934991439724}             CULIACAN
# 2      {'LOCATION': 0.88592453954918}  PALACIO DE GOBIERNO
# 3  {'ORGANIZATION': 0.44361875069213}                STATE
# 4      {'LOCATION': 0.86880109112666}            FRESNILLO
#
#                                                   h1  \
# 0  Cenace advierte de nuevos cortes de luz “rotat...
# 1  Madres rastreadoras de Sinaloa exigen la desti...
# 2  Madres rastreadoras de Sinaloa exigen la desti...
# 3  Madres rastreadoras de Sinaloa exigen la desti...
# 4  “Ya no hagan de emoción”: Forcejean a llegada ...
#
#                              wikidata_search_entries  \
# 0  [{'id': 'Q80269', 'display_label': 'Zacatecas'...
# 1  [{'id': 'Q211760', 'display_label': 'Culiacán'...
# 2  [{'id': 'Q385938', 'display_label': 'Governmen...
# 3  [{'id': 'Q7275', 'display_label': 'state', 'di...
# 4  [{'id': 'Q1816543', 'display_label': 'Fresnill...
#
#                                                   ix  \
# 0  Zacatecas-Cenace advierte de nuevos cortes de ...
# 1  Culiacán-Madres rastreadoras de Sinaloa exigen...
# 2  Palacio de Gobierno-Madres rastreadoras de Sin...
# 3  State-Madres rastreadoras de Sinaloa exigen la...
# 4  Fresnillo-“Ya no hagan de emoción”: Forcejean ...
#
#                                            sb_answer  \
# 0  The news article is most likely referring to: ...
# 1  The news article is most likely referring to: ...
# 2  The news article is most likely referring to: ...
# 3  The news article is most likely referring to: ...
# 4  The news article is most likely referring to: ...
#
#                                        options_given  \
# 0  1. Zacatecas, state of Mexico \n2. Zacatecas, ...
# 1  1. Culiacán, capital and largest city in the M...
# 2  1. Government Palace, seat of the executive br...
# 3  1. state, organised community living under a s...
# 4  1. Fresnillo, city in Fresnillo Municipality, ...
#
#                                           content_en  \
# 0  The National Energy Control Center (Cenace) an...
# 1  Culiacán, Sin.- In the esplanade of Palacio de...
# 2  Culiacán, Sin.- In the esplanade of Palacio de...
# 3  Culiacán, Sin.- In the esplanade of Palacio de...
# 4  Fresnillo, Zacatecas.- President Andrés Manuel...
#
#                                   label_desc_options  \
# 0  [Zacatecas, state of Mexico, Zacatecas, city i...
# 1  [Culiacán, capital and largest city in the Mex...
# 2  [Government Palace, seat of the executive bran...
# 3  [state, organised community living under a sys...
# 4  [Fresnillo, city in Fresnillo Municipality, Za...
#
#                                       sents_with_ent  sents_len  \
# 0  [The blackout started at 7:58 a.m. on Monday, ...          1
# 1  [Culiacán, Sin.- In the esplanade of Palacio d...          1
# 2  [Culiacán, Sin.- In the esplanade of Palacio d...          1
# 3  [On 16 February, the Attorney General of the S...          1
# 4  [Fresnillo, Zacatecas.- President Andrés Manue...          1
#
#                                      sb_option_given  index_of_option_given
# 0  Zacatecas, city in Zacatecas Municipality, Zac...                      1
# 1  Culiacán, capital and largest city in the Mexi...                      0
# 2  Palacio de Gobierno de Jalisco, Government bui...                      1
# 3  state, organised community living under a syst...                      0
# 4  Fresnillo, city in Fresnillo Municipality, Zac...                      0

# %%
bert_ned = BertNED()

# %%
all_obs = validation_df.shape[0]
best_ixs = []
for i, obs in enumerate(validation_df.to_dict(orient='records')):
    print_progress_bar(iteration=i, total=all_obs)
    try:
        best_option_ix = bert_ned.desambiguate(
            entity=obs['text'], 
            contexts=obs['sents_with_ent'], 
            options=obs['label_desc_options']
        )
        best_ixs.append(best_option_ix)
    except Exception as e:
        print(i)
        raise e
# Out:
# Progress: [=======================================           ] 80%
# Token indices sequence length is longer than the specified maximum sequence length for this model (746 > 512). Running this sequence through the model will result in indexing errors
# Progress: [================================================= ] 99%

# %%
validation_df['bert_best_option_ix'] = best_ixs

# %%
validation_df.head(5)
# Out:
#    index                 text           ner  \
# 0      0            Zacatecas          CITY
# 1      1             Culiacán        PERSON
# 2      2  Palacio de Gobierno      LOCATION
# 3      3                State  ORGANIZATION
# 4      4            Fresnillo          CITY
#
#                        nerConfidences           clean_text  \
# 0      {'LOCATION': 0.98695854325281}            ZACATECAS
# 1        {'PERSON': 0.43934991439724}             CULIACAN
# 2      {'LOCATION': 0.88592453954918}  PALACIO DE GOBIERNO
# 3  {'ORGANIZATION': 0.44361875069213}                STATE
# 4      {'LOCATION': 0.86880109112666}            FRESNILLO
#
#                                                   h1  \
# 0  Cenace advierte de nuevos cortes de luz “rotat...
# 1  Madres rastreadoras de Sinaloa exigen la desti...
# 2  Madres rastreadoras de Sinaloa exigen la desti...
# 3  Madres rastreadoras de Sinaloa exigen la desti...
# 4  “Ya no hagan de emoción”: Forcejean a llegada ...
#
#                              wikidata_search_entries  \
# 0  [{'id': 'Q80269', 'display_label': 'Zacatecas'...
# 1  [{'id': 'Q211760', 'display_label': 'Culiacán'...
# 2  [{'id': 'Q385938', 'display_label': 'Governmen...
# 3  [{'id': 'Q7275', 'display_label': 'state', 'di...
# 4  [{'id': 'Q1816543', 'display_label': 'Fresnill...
#
#                                                   ix  \
# 0  Zacatecas-Cenace advierte de nuevos cortes de ...
# 1  Culiacán-Madres rastreadoras de Sinaloa exigen...
# 2  Palacio de Gobierno-Madres rastreadoras de Sin...
# 3  State-Madres rastreadoras de Sinaloa exigen la...
# 4  Fresnillo-“Ya no hagan de emoción”: Forcejean ...
#
#                                            sb_answer  \
# 0  The news article is most likely referring to: ...
# 1  The news article is most likely referring to: ...
# 2  The news article is most likely referring to: ...
# 3  The news article is most likely referring to: ...
# 4  The news article is most likely referring to: ...
#
#                                        options_given  \
# 0  1. Zacatecas, state of Mexico \n2. Zacatecas, ...
# 1  1. Culiacán, capital and largest city in the M...
# 2  1. Government Palace, seat of the executive br...
# 3  1. state, organised community living under a s...
# 4  1. Fresnillo, city in Fresnillo Municipality, ...
#
#                                           content_en  \
# 0  The National Energy Control Center (Cenace) an...
# 1  Culiacán, Sin.- In the esplanade of Palacio de...
# 2  Culiacán, Sin.- In the esplanade of Palacio de...
# 3  Culiacán, Sin.- In the esplanade of Palacio de...
# 4  Fresnillo, Zacatecas.- President Andrés Manuel...
#
#                                   label_desc_options  \
# 0  [Zacatecas, state of Mexico, Zacatecas, city i...
# 1  [Culiacán, capital and largest city in the Mex...
# 2  [Government Palace, seat of the executive bran...
# 3  [state, organised community living under a sys...
# 4  [Fresnillo, city in Fresnillo Municipality, Za...
#
#                                       sents_with_ent  sents_len  \
# 0  [The blackout started at 7:58 a.m. on Monday, ...          1
# 1  [Culiacán, Sin.- In the esplanade of Palacio d...          1
# 2  [Culiacán, Sin.- In the esplanade of Palacio d...          1
# 3  [On 16 February, the Attorney General of the S...          1
# 4  [Fresnillo, Zacatecas.- President Andrés Manue...          1
#
#                                      sb_option_given  index_of_option_given  \
# 0  Zacatecas, city in Zacatecas Municipality, Zac...                      1
# 1  Culiacán, capital and largest city in the Mexi...                      0
# 2  Palacio de Gobierno de Jalisco, Government bui...                      1
# 3  state, organised community living under a syst...                      0
# 4  Fresnillo, city in Fresnillo Municipality, Zac...                      0
#
#    bert_best_option_ix
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
validation_df['bert!=sb'] = validation_df['bert_best_option_ix'] != validation_df['index_of_option_given']

# %%
print(
    "Accuracy against StableBelgua Answers: {0}".format(1 - validation_df['bert!=sb'].mean())
)
# Out:
# Accuracy against StableBelgua Answers: 0.8655023371340282

# %%
validation_df[validation_df['bert!=sb']]
# Out:
#        index                 text           ner  \
# 2          2  Palacio de Gobierno      LOCATION
# 8          8        Rocca di Papa          CITY
# 9          9             Velletri        PERSON
# 12        12               Latina          CITY
# 31        31               Tonalá      LOCATION
# ...      ...                  ...           ...
# 51106  51106              Justice  ORGANIZATION
# 51112  51112                 IAFA  ORGANIZATION
# 51114  51114                 AIFM  ORGANIZATION
# 51124  51124                Altos          CITY
# 51125  51125            Hornos de      LOCATION
#
#                            nerConfidences           clean_text  \
# 2          {'LOCATION': 0.88592453954918}  PALACIO DE GOBIERNO
# 8      {'ORGANIZATION': 0.59307377723601}        ROCCA DI PAPA
# 9              {'PERSON': 0.579953265056}             VELLETRI
# 12          {'LOCATION': 0.9307302010545}               LATINA
# 31         {'LOCATION': 0.47620629578128}               TONALA
# ...                                   ...                  ...
# 51106  {'ORGANIZATION': 0.60568609396161}              JUSTICE
# 51112  {'ORGANIZATION': 0.98692864204234}                 IAFA
# 51114  {'ORGANIZATION': 0.75837510148933}                 AIFM
# 51124      {'LOCATION': 0.83581962406358}                ALTOS
# 51125      {'LOCATION': 0.83812977860521}            HORNOS DE
#
#                                                       h1  \
# 2      Madres rastreadoras de Sinaloa exigen la desti...
# 8      Detienen a narcofamilia en Italia; niña de 7 a...
# 9      Detienen a narcofamilia en Italia; niña de 7 a...
# 12     Detienen a narcofamilia en Italia; niña de 7 a...
# 31     Golfo, CJNG y Sinaloa, detrás del tráfico de m...
# ...                                                  ...
# 51106  Una pizca de los desencuentros teóricos en Amé...
# 51112  México ocupa presidencia del Consejo de Autori...
# 51114  México ocupa presidencia del Consejo de Autori...
# 51124  Mexico’s Financial Intelligence Unit freezes 1...
# 51125  Mexico’s Financial Intelligence Unit freezes 1...
#
#                                  wikidata_search_entries  \
# 2      [{'id': 'Q385938', 'display_label': 'Governmen...
# 8      [{'id': 'Q243228', 'display_label': 'Rocca di ...
# 9      [{'id': 'Q189236', 'display_label': 'Velletri'...
# 12     [{'id': 'Q13410', 'display_label': 'Latina', '...
# 31     [{'id': 'Q2636407', 'display_label': 'Tonalá',...
# ...                                                  ...
# 51106  [{'id': 'Q16533', 'display_label': 'judge', 'd...
# 51112  [{'id': 'Q21015750', 'display_label': 'Interna...
# 51114  [{'id': 'Q119477776', 'display_label': 'AIFM -...
# 51124  [{'id': 'Q22060469', 'display_label': 'Altos',...
# 51125  [{'id': 'Q1646952', 'display_label': 'Hornos d...
#
#                                                       ix  \
# 2      Palacio de Gobierno-Madres rastreadoras de Sin...
# 8      Rocca di Papa-Detienen a narcofamilia en Itali...
# 9      Velletri-Detienen a narcofamilia en Italia; ni...
# 12     Latina-Detienen a narcofamilia en Italia; niña...
# 31     Tonalá-Golfo, CJNG y Sinaloa, detrás del tráfi...
# ...                                                  ...
# 51106  Justice-Una pizca de los desencuentros teórico...
# 51112  IAFA-México ocupa presidencia del Consejo de A...
# 51114  AIFM-México ocupa presidencia del Consejo de A...
# 51124  Altos-Mexico’s Financial Intelligence Unit fre...
# 51125  Hornos de-Mexico’s Financial Intelligence Unit...
#
#                                                sb_answer  \
# 2      The news article is most likely referring to: ...
# 8      The news article is most likely referring to: ...
# 9      The news article is most likely referring to: ...
# 12     The news article is most likely referring to: ...
# 31     The news article is most likely referring to: ...
# ...                                                  ...
# 51106  The news article is most likely referring to: ...
# 51112  The news article is most likely referring to: ...
# 51114  The news article is most likely referring to: ...
# 51124  The news article is most likely referring to: ...
# 51125  The news article is most likely referring to: ...
#
#                                            options_given  \
# 2      1. Government Palace, seat of the executive br...
# 8      1. Rocca di Papa, Italian comune \n2. Rocca di...
# 9      1. Velletri, Italian comune \n2. Velletri, chi...
# 12     1. Latina, Italian comune \n2. Latino, people ...
# 31     1. Tonalá, municipality of Chiapas, Mexico \n2...
# ...                                                  ...
# 51106  1. judge, official who presides over court pro...
# 51112  1. International Association for the Fantastic...
# 51114  1. AIFM - Associazione italiana Finiture dei M...
# 51124  1. Altos, Brazilian municipality of the state ...
# 51125  1. Hornos de Moncalvillo, municipality in Spai...
#
#                                               content_en  \
# 2      Culiacán, Sin.- In the esplanade of Palacio de...
# 8      The Italian police arrested mother and daughte...
# 9      The Italian police arrested mother and daughte...
# 12     The Italian police arrested mother and daughte...
# 31     Cells of the Gulf cartels, Sinaloa and Jalisco...
# ...                                                  ...
# 51106  A. Bartra, professor at the UAM (Campesindios....
# 51112  The Ministry of Foreign Affairs reported that ...
# 51114  The Ministry of Foreign Affairs reported that ...
# 51124  Santiago Nieto, the head of the Financial Inte...
# 51125  Santiago Nieto, the head of the Financial Inte...
#
#                                       label_desc_options  \
# 2      [Government Palace, seat of the executive bran...
# 8      [Rocca di Papa, Italian comune, Rocca di Papa,...
# 9      [Velletri, Italian comune, Velletri, chief tow...
# 12     [Latina, Italian comune, Latino, people in the...
# 31     [Tonalá, municipality of Chiapas, Mexico, Tona...
# ...                                                  ...
# 51106  [judge, official who presides over court proce...
# 51112  [International Association for the Fantastic i...
# 51114  [AIFM - Associazione italiana Finiture dei Met...
# 51124  [Altos, Brazilian municipality of the state of...
# 51125  [Hornos de Moncalvillo, municipality in Spain,...
#
#                                           sents_with_ent  sents_len  \
# 2      [Culiacán, Sin.- In the esplanade of Palacio d...          1
# 8      [According to information published this Tuesd...          1
# 9      [The family earned up to $2,200 a day, accordi...          1
# 12     [The women, according to La Repubblica, are ac...          2
# 31     [These localities are Arriaga, Tonalá, Cintala...          1
# ...                                                  ...        ...
# 51106  [In the need to find and articulate efforts, i...          1
# 51112  [The Ministry of Foreign Affairs reported that...          1
# 51114  [In a statement, the Chancellery stated that t...          3
# 51124  [In an interview, Santiago Nieto explained tha...          1
# 51125  [In an interview, Santiago Nieto explained tha...          1
#
#                                          sb_option_given  \
# 2      Palacio de Gobierno de Jalisco, Government bui...
# 8      Rocca di Papa, chief town of the homonym munic...
# 9                               Velletri, Italian comune
# 12                                Latina, Italian comune
# 31               Tonalá, municipality of Chiapas, Mexico
# ...                                                  ...
# 51106  justice, broad idea of a situation where peopl...
# 51112                                         IAFA Award
# 51114  Apoptosis-inducing factor, mitochondrion-assoc...
# 51124   Altos, city and district in Cordillera, Paraguay
# 51125                         Hornos de cal de la Guirra
#
#        index_of_option_given  bert_best_option_ix  bert!=sb
# 2                          1                    0      True
# 8                          1                    5      True
# 9                          0                    3      True
# 12                         0                    6      True
# 31                         0                    1      True
# ...                      ...                  ...       ...
# 51106                      1                    0      True
# 51112                      5                    3      True
# 51114                      3                    2      True
# 51124                      1                    6      True
# 51125                      1                    6      True
#
# [6877 rows x 18 columns]

# %%
for ent in sorted(validation_df[validation_df['bert!=sb']]['text'].unique()):
    print(ent)
# Out:
# 7th & Union
# A.C
# A.T. Kearney
# AAA
# ABC
# AFI
# AFP
# AGA
# AIC
# AICM
# AIDA
# AIFM
# AJ
# AL
# ALARMA
# ALDF
# ALYC
# AMANC
# AMG
# AMIA
# ANAM
# ANDA
# AOL
# AP
# APA
# ASA
# ASF
# ASIP
# ASL
# Aafia Siddiqui
# Aaron Robinson
# Aaron Stein
# Abarca
# Abasolo
# Abbott
# Abdul
# Abelardo L. Rodríguez
# Abingdon
# Abraham Lincoln
# Abraham Mendoza
# Abramo
# Abu Muhammad
# Abundis
# Academy of Engineering
# Academy of Fine Arts
# Acapulco
# Acatlán de
# Acayucan
# Acciona
# Aceves
# Achilles
# Acklins
# Acteal
# Actopan
# Acuña
# Administrative Committee
# Adolfo López Mateos
# Adolfo Marsillach
# Adrian
# Adriana Figueroa
# Adriana Pérez
# Adriel
# Adrien
# Adrián González
# Adrián Marcelo
# Adrián Vázquez
# Adrián Ávalos
# Aeromexico
# Afghanistan
# Afore
# Africa
# Agache
# Agua Dulce
# Aguirre
# Agusto
# Ahmad
# Ahmaud Arbery
# Aila
# Aimée
# Air Force Command
# Air Force Museum
# Airbus Group
# Akihabara
# Al
# Al Arabiya
# Al Jazeera
# Al Qaeda
# Al Zubarah
# Al-Quds
# Alaba
# Alan Garcia
# Alan Ituriel
# Alatorre
# Alatrist
# Alba
# Alba Flores
# Albert Einstein
# Albert Zhang
# Alberti
# Albon
# Alcala
# Alcázar de
# Aldama
# Aldesa
# Alebrijes
# Alejandra
# Alejandro
# Alejandro Aguilera
# Alejandro Damián
# Alejandro Díaz
# Alejandro Encinas
# Alejandro Fernández
# Alejandro Llano
# Alejandro López
# Alejandro Macías
# Alejandro Martínez
# Alejandro Nieto
# Alejandro Ramírez
# Alejandro Rubio
# Alejandro Sánchez
# Alejandro Vargas
# Aleksand
# Aleph
# Alessandra
# Alex
# Alex Berger
# Alexander Müller
# Alexandre
# Alexandria
# Alexis
# Alfonso
# Alfonso Navarrete
# Alfonso Rodríguez
# Alfonso Romo
# Alfonso Suárez
# Alfredo Félix
# Alfredo González
# Alfredo Gutiérrez
# Alfredo II
# Alfredo Morales
# Alfredo Suárez
# Ali
# All Power
# Alla
# Allegri
# Allen
# Allende
# Allison Christians
# Almodóvar
# Alpizar
# Altamira
# Altamirano
# Altiplano
# Altos
# Alvarado
# Alvaro
# Amacuzac
# Amaro
# Amazon
# Amazonas
# America
# American Armed Forces
# American Embassy
# American Union
# American-Israeli
# Americas
# Americo
# Amistad
# Amnesty International
# Amor
# Amorós
# Amozoc
# Amparo
# Amparo Fernández
# Amrest
# Amsterdam
# América Latina
# Américo Villarreal
# Ana
# Ana Lucía
# Ana Teresa
# Analú
# Anatole
# Anaya
# Anayas
# Andahuaylas
# Anderson
# Andrade
# Andretti
# Andrew
# Andrew Goddard
# Andrews Air Force Base
# William Campbell
# William J. Perry
# William Scott
# Williams
# Williamsburg
# Willie Colón
# Willy
# Wilson
# Windsor
# Wiseman
# Wisin
# Wolfsburg
# Woodside
# Woody
# World Association
# World Bank
# World Bank Group
# World Committee
# World Economic Forum
# World Gold Council
# World Organization
# World Trade Center
# Wray
# Wuhan
# Xavier
# Xavier Font
# Ximena
# Xochimilco
# Xochistlahuaca
# Xóchitl Álvarez
# YUKON
# Yafa
# Yahoo
# Yan
# Yaner
# Yanit
# Yaqui
# Yaquis
# Yasnaya
# Yautepec
# Yayo
# Yazan
# Yeda
# Yehualtepec
# Yeimi
# Yelenovka
# Yemen
# Yesenia
# Yo-Yo Ma
# Yoichi Takahashi
# Yolanda
# Yoon
# Yorio
# YouTube
# Youth Front
# Youyang Gu
# Ysidro
# Yucatan
# Yucatec
# Yucateco
# Yucatán
# Yuri
# Yvonne Doyle
# ZDF
# Zacatecas
# Zacatelco
# Zacualpan
# Zacualtipan
# Zakharova
# Zambada
# Zambrana
# Zapata
# Zaragoza
# Zarco
# Zechariah
# Zenit
# Zhang Shilong
# Zhezkazgan
# Zhihu
# Zhong An
# Zhu Hua
# Zilis
# Zimapán
# Zion
# Zona
# Zonana
# Zuavos
# Zurich
# Zurita
# al Qaeda
# bohemia
# chile
# de
# de Aragón
# de Dios
# de Jesús
# de León
# de Sousa
# de Villa
# de la Cueva
# de los
# del
# del Río
# del Valle
# guinea
# la Libertad
# la Reforma
# new Washington
# northern
# of Rectory
# the Argentine
# the states
# viru
# Álex Fernández
# Álex García
# Álvarez Icaza
# Álvaro Brechner
# Álvaro Cervera
# Álvaro Gandul
# Álvaro García
# Álvaro Giménez
# Álvaro Obregón
# Álvaro Pereira
# Álvaro Sánchez
# Ángel Colín
# Ángel Cruz
# Ángel Guitérrez
# Ángeles Ayala
# Ángeles Huerta
# Éder Martins
# Édgar Karam
# Édgar Tenorio
# Élie-Frédéric Forey
# Ñico Saquito
# Óscar Chavez
# Óscar Chávez
# Óscar Córdoba

# %%
validation_df[
    (validation_df['bert!=sb'])&
    (validation_df['text']=='Enrique Peña Nieto')
]
# Out:
#        index                text     ner                nerConfidences  \
# 22067  22067  Enrique Peña Nieto  PERSON  {'PERSON': 0.85535035710227}
# 32914  32914  Enrique Peña Nieto  PERSON  {'PERSON': 0.99699559005229}
# 47489  47489  Enrique Peña Nieto  PERSON  {'PERSON': 0.88057265245543}
#
#                clean_text                                                 h1  \
# 22067  ENRIQUE PENA NIETO  “Le creo al ministro Zaldívar”: AMLO tras decl...
# 32914  ENRIQUE PENA NIETO  Críticas de exsecretarios de Salud, por intere...
# 47489  ENRIQUE PENA NIETO  La Mansión del Bienestar: el fracaso de la doc...
#
#                                  wikidata_search_entries  \
# 22067  [{'id': 'Q296741', 'display_label': 'Enrique P...
# 32914  [{'id': 'Q296741', 'display_label': 'Enrique P...
# 47489  [{'id': 'Q296741', 'display_label': 'Enrique P...
#
#                                                       ix  \
# 22067  Enrique Peña Nieto-“Le creo al ministro Zaldív...
# 32914  Enrique Peña Nieto-Críticas de exsecretarios d...
# 47489  Enrique Peña Nieto-La Mansión del Bienestar: e...
#
#                                                sb_answer  \
# 22067  The news article is most likely referring to: ...
# 32914  The news article is most likely referring to: ...
# 47489  The news article is most likely referring to: ...
#
#                                            options_given  \
# 22067  1. Enrique Peña Nieto, 64th President of Mexic...
# 32914  1. Enrique Peña Nieto, 64th President of Mexic...
# 47489  1. Enrique Peña Nieto, 64th President of Mexic...
#
#                                               content_en  \
# 22067  President Andrés Manuel López Obrador said tha...
# 32914  President Andrés Manuel López Obrador said he ...
# 47489  Even the hesitant has denoised the lifestyle o...
#
#                                       label_desc_options  \
# 22067  [Enrique Peña Nieto, 64th President of Mexico,...
# 32914  [Enrique Peña Nieto, 64th President of Mexico,...
# 47489  [Enrique Peña Nieto, 64th President of Mexico,...
#
#                                           sents_with_ent  sents_len  \
# 22067  [In Palacio Nacional, the federal governor who...          1
# 32914  [In the virtual forum “The Moment of the Epide...          1
# 47489  [In national life this is not a novel episode,...          1
#
#                                          sb_option_given  \
# 22067  Enrique Peña Nieto conflict of interest scanda...
# 32914  Enrique Peña Nieto conflict of interest scanda...
# 47489  Enrique Peña Nieto conflict of interest scanda...
#
#        index_of_option_given  bert_best_option_ix  bert!=sb
# 22067                      1                    0      True
# 32914                      1                    0      True
# 47489                      1                    0      True

# %%
ix = np.random.choice(validation_df[
    (validation_df['bert!=sb'])&
    (validation_df['text']=='Enrique Peña Nieto')
].index)
#ix = np.random.randint(0,validation_df[validation_df['bert!=sb']].shape[0])

# %%
ix
# Out:
# 32914

# %%
ent = validation_df[validation_df['bert!=sb']].loc[ix]['text']

options = validation_df[validation_df['bert!=sb']].loc[ix]['label_desc_options']

sb_answer_ix = validation_df[validation_df['bert!=sb']].loc[ix]['index_of_option_given']
sb_answer = options[sb_answer_ix]
bert_answer_ix = validation_df[validation_df['bert!=sb']].loc[ix]['bert_best_option_ix']
bert_answer = options[bert_answer_ix]

print("Entity: {0}".format(ent))
print("SB answer: {0}".format(sb_answer))
print("Bert answer: {0}".format(bert_answer))
# Out:
# Entity: Enrique Peña Nieto
# SB answer: Enrique Peña Nieto conflict of interest scandal, Political scandal in Mexico in 2015
# Bert answer: Enrique Peña Nieto, 64th President of Mexico

# %%
validation_df[validation_df['bert!=sb']].loc[ix]['sents_with_ent']
# Out:
# ['The "PLEITO" CALDERÓN VS RODRÍGUEZ PRATS Anaya Cortés eluded to answer the lawsuit of former President Felipe Calderón Hinojosa and Juan José Rodríguez Pratts and to have orchestrated it.']

# %%
validation_df[validation_df['bert!=sb']].loc[ix]['content_en']
# Out:
# 'From Ernesto Ruffo Appel’s discovery, who yesterday confirmed that he does want to be the PAN’s candidate for the presidency of the Republic for 2018 and that some of his co-religionists consider that he has greater merit in leading Acción Nacional than many of the aspirants, the national leader of the albiazul, Ricardo Anaya Cortés, pointed out: “I have deep admiration and respect for him.” Questioned that the former president has more experience and trajectory than Anaya Cortés himself, Margarita Zavala and others, the PAN leader recalled that Ernesto was the first governor in Mexico\'s history not to be emanated from the PRI. “It was the first postulated by the PAN in that historic triumph of 1989, I have nothing but admiration and respect for it,” he stressed of the Baja Californian who is already beginning to receive support on social networks and trusts that the “Ruffomania” will be unleashed. In support of the PAN candidate for Saltillo’s mayor’s office, Esther Quintana Salinas, Anaya Cortés offered a press conference in the “Acuña” square in the city center, where she did not admit or reject that Ruffo Appel is, according to some PAN members, the best letter to regain the presidency of Mexico next year. About Margarita Zavala, who was informed “does not lift” because she gathered few people on her last visit to Piedras Negras, replied: “I also have affection for her, respect, she is my party partner.” As usual, he ignored being interested in participating in the presidential race, despite the fact that some of the candidates point him out to act as “judge and part.” Although he is a public who pretends to be the presidential nominee, the PAN leader answered with his simple “No,” and thus refuted that he is on both sides in this matter of being the one appointed to fight for relief in the federal government. He argued that they are now only concentrated in the local elections in Coahuila, State of Mexico, Nayarit and Veracruz, and that they will see that later. The "PLEITO" CALDERÓN VS RODRÍGUEZ PRATS Anaya Cortés eluded to answer the lawsuit of former President Felipe Calderón Hinojosa and Juan José Rodríguez Pratts and to have orchestrated it. "It is mentioned that you are behind Rodríguez Prats," the former senator was told that in the PAN National Political Council he claimed the former president of the Republic, Felipe Calderón: "It is enough that you want to impose on your wife (Margarita Zavala as a presidential candidate)." Instead, he said that “the agreement of the National Council is very clear, to concentrate on this year’s elections and I reiterate the call I have made to unity and to concentrate on winning the elections. “Particularly that Esther wins and in achieving political alternation here in Coahuila, so that there is the change that suits people, my call is to unity,” he argued and avoided accepting or rejecting. afcl'

# %%
bert_ned = BertNED()

# %%
bert_ned._compute_scores(
    entity=validation_df.iloc[41308]['text'], 
    context=validation_df.iloc[41308]['sents_with_ent'][1], 
    options=validation_df.iloc[41308]['label_desc_options']
)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (746 > 512). Running this sequence through the model will result in indexing errors
# 746
# These are the 10 best paid careers in Mexico Engineering in Urban Mobility: UPIEM Engineering in Energy Business Sustainable: UPIEM Industrial Robotic Engineering: ESIME Unit Azcapotzalco Engineering in Environmental Sciences: ENCB Engineering in Automotive Systems
# 80
# 83
# 83
# 90
# 87
# 82
# 86
# array([[4.6752747e-03, 9.9532473e-01],
#        [9.7041839e-01, 2.9581612e-02],
#        [9.9965370e-01, 3.4633253e-04],
#        [9.9969864e-01, 3.0143259e-04],
#        [9.9970406e-01, 2.9587332e-04],
#        [9.9969995e-01, 3.0008118e-04],
#        [9.9969935e-01, 3.0068430e-04]], dtype=float32)

# %%
import time

# %%
start = time.time()
validation_df['bert_best_option_ix'] = validation_df.apply(
    lambda row: desambiguate(
        entity=row['text'], 
        contexts=row['sents_with_ent'], 
        options=row['label_desc_options']
    ), axis=1
)
end = time.time()
print(end-start)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (746 > 512). Running this sequence through the model will result in indexing errors
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[31], line 2
#       1 start = time.time()
# ----> 2 validation_df['bert_best_option_ix'] = validation_df.apply(
#       3     lambda row: desambiguate(
#       4         entity=row['text'],
#       5         contexts=row['sents_with_ent'],
#       6         options=row['label_desc_options']
#       7     ), axis=1
#       8 )
#       9 end = time.time()
#      10 print(end-start)
#
# File ~\~\venvs\summaries\Lib\site-packages\pandas\core\frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File ~\~\venvs\summaries\Lib\site-packages\pandas\core\apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File ~\~\venvs\summaries\Lib\site-packages\pandas\core\apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
#     800     # wrap results
#     801     return self.wrap_results(results, res_index)
#
# File ~\~\venvs\summaries\Lib\site-packages\pandas\core\apply.py:814, in FrameApply.apply_series_generator(self)
#     811 with option_context("mode.chained_assignment", None):
#     812     for i, v in enumerate(series_gen):
#     813         # ignore SettingWithCopy here in case the user mutates
# --> 814         results[i] = self.f(v)
#     815         if isinstance(results[i], ABCSeries):
#     816             # If we have a view on v, we need to make a copy because
#     817             #  series_generator will swap out the underlying data
#     818             results[i] = results[i].copy(deep=False)
#
# Cell In[31], line 3, in <lambda>(row)
#       1 start = time.time()
#       2 validation_df['bert_best_option_ix'] = validation_df.apply(
# ----> 3     lambda row: desambiguate(
#       4         entity=row['text'],
#       5         contexts=row['sents_with_ent'],
#       6         options=row['label_desc_options']
#       7     ), axis=1
#       8 )
#       9 end = time.time()
#      10 print(end-start)
#
# Cell In[27], line 56, in desambiguate(entity, contexts, options, verbose)
#      54 sents_scores = []
#      55 for context in contexts:
# ---> 56     scores = compute_scores(entity, context, options)
#      57     # append probabilities of belonging to class 1 (for each option)
#      58     sents_scores.append(np.array(scores)[:,1])
#
# Cell In[27], line 37, in compute_scores(entity, context, options)
#      26 encoded_dict = tokenizer.encode_plus(
#      27     query,                           # Sentence to encode.
#      28     add_special_tokens = True,       # Add '[CLS]' and '[SEP]'
#    (...)
#      33     return_tensors = 'pt',           # Return pytorch tensors.
#      34 )
#      36 if len(encoded_dict['input_ids'])<=512:
# ---> 37     prob = predict_proba(
#      38         input_ids=encoded_dict['input_ids'],
#      39         attention_mask=encoded_dict['attention_mask']
#      40     )
#      41     scores.append(prob)
#      42     break
#
# Cell In[27], line 5, in predict_proba(input_ids, attention_mask)
#       3 att_msk = attention_mask.to("cuda:0")
#       4 with torch.no_grad():
# ----> 5     outputs = model(
#       6         input_ids=iids,
#       7         token_type_ids=None,
#       8         attention_mask=att_msk
#       9     )
#      11 logits = outputs.logits
#      12 # Move logits and labels to CPU
#      13 # Use softmax to get probabilities
#
# File ~\~\venvs\summaries\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\~\venvs\summaries\Lib\site-packages\transformers\models\bert\modeling_bert.py:1562, in BertForSequenceClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1554 r"""
#    1555 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#    1556     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#    1557     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#    1558     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1559 """
#    1560 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1562 outputs = self.bert(
#    1563     input_ids,
#    1564     attention_mask=attention_mask,
#    1565     token_type_ids=token_type_ids,
#    1566     position_ids=position_ids,
#    1567     head_mask=head_mask,
#    1568     inputs_embeds=inputs_embeds,
#    1569     output_attentions=output_attentions,
#    1570     output_hidden_states=output_hidden_states,
#    1571     return_dict=return_dict,
#    1572 )
#    1574 pooled_output = outputs[1]
#    1576 pooled_output = self.dropout(pooled_output)
#
# File ~\~\venvs\summaries\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\~\venvs\summaries\Lib\site-packages\transformers\models\bert\modeling_bert.py:986, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     984 if hasattr(self.embeddings, "token_type_ids"):
#     985     buffered_token_type_ids = self.embeddings.token_type_ids[:, :seq_length]
# --> 986     buffered_token_type_ids_expanded = buffered_token_type_ids.expand(batch_size, seq_length)
#     987     token_type_ids = buffered_token_type_ids_expanded
#     988 else:
#
# RuntimeError: The expanded size of the tensor (746) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 746].  Tensor sizes: [1, 512]

# %%
validation_df
# Out:
#        index                 text           ner  \
# 0          0            Zacatecas          CITY
# 1          1             Culiacán        PERSON
# 2          2  Palacio de Gobierno      LOCATION
# 3          3                State  ORGANIZATION
# 4          4            Fresnillo          CITY
# ...      ...                  ...           ...
# 51126  51126               Mexico       COUNTRY
# 51127  51127             Santiago          CITY
# 51128  51128           Peña Nieto        PERSON
# 51129  51129                Pemex  ORGANIZATION
# 51130  51130               Toluca          CITY
#
#                            nerConfidences           clean_text  \
# 0          {'LOCATION': 0.98695854325281}            ZACATECAS
# 1            {'PERSON': 0.43934991439724}             CULIACAN
# 2          {'LOCATION': 0.88592453954918}  PALACIO DE GOBIERNO
# 3      {'ORGANIZATION': 0.44361875069213}                STATE
# 4          {'LOCATION': 0.86880109112666}            FRESNILLO
# ...                                   ...                  ...
# 51126      {'LOCATION': 0.86121711995959}               MEXICO
# 51127      {'LOCATION': 0.60977913237806}             SANTIAGO
# 51128        {'PERSON': 0.74281429426886}           PENA NIETO
# 51129  {'ORGANIZATION': 0.96210365359227}                PEMEX
# 51130      {'LOCATION': 0.98220323937029}               TOLUCA
#
#                                                       h1  \
# 0      Cenace advierte de nuevos cortes de luz “rotat...
# 1      Madres rastreadoras de Sinaloa exigen la desti...
# 2      Madres rastreadoras de Sinaloa exigen la desti...
# 3      Madres rastreadoras de Sinaloa exigen la desti...
# 4      “Ya no hagan de emoción”: Forcejean a llegada ...
# ...                                                  ...
# 51126  Mexico’s Financial Intelligence Unit freezes 1...
# 51127  Mexico’s Financial Intelligence Unit freezes 1...
# 51128  Mexico’s Financial Intelligence Unit freezes 1...
# 51129  Cofece investiga, otra vez, comercialización d...
# 51130  Cuestionan a Morena por abstenerse a participa...
#
#                                  wikidata_search_entries  \
# 0      [{'id': 'Q80269', 'display_label': 'Zacatecas'...
# 1      [{'id': 'Q211760', 'display_label': 'Culiacán'...
# 2      [{'id': 'Q385938', 'display_label': 'Governmen...
# 3      [{'id': 'Q7275', 'display_label': 'state', 'di...
# 4      [{'id': 'Q1816543', 'display_label': 'Fresnill...
# ...                                                  ...
# 51126  [{'id': 'Q96', 'display_label': 'Mexico', 'dis...
# 51127  [{'id': 'Q2887', 'display_label': 'Santiago', ...
# 51128  [{'id': 'Q296741', 'display_label': 'Enrique P...
# 51129  [{'id': 'Q871308', 'display_label': 'Pemex', '...
# 51130  [{'id': 'Q209034', 'display_label': 'Toluca', ...
#
#                                                       ix  \
# 0      Zacatecas-Cenace advierte de nuevos cortes de ...
# 1      Culiacán-Madres rastreadoras de Sinaloa exigen...
# 2      Palacio de Gobierno-Madres rastreadoras de Sin...
# 3      State-Madres rastreadoras de Sinaloa exigen la...
# 4      Fresnillo-“Ya no hagan de emoción”: Forcejean ...
# ...                                                  ...
# 51126  Mexico-Mexico’s Financial Intelligence Unit fr...
# 51127  Santiago-Mexico’s Financial Intelligence Unit ...
# 51128  Peña Nieto-Mexico’s Financial Intelligence Uni...
# 51129  Pemex-Cofece investiga, otra vez, comercializa...
# 51130  Toluca-Cuestionan a Morena por abstenerse a pa...
#
#                                                sb_answer  \
# 0      The news article is most likely referring to: ...
# 1      The news article is most likely referring to: ...
# 2      The news article is most likely referring to: ...
# 3      The news article is most likely referring to: ...
# 4      The news article is most likely referring to: ...
# ...                                                  ...
# 51126  The news article is most likely referring to: ...
# 51127  The news article is most likely referring to: ...
# 51128  The news article is most likely referring to: ...
# 51129  The news article is most likely referring to: ...
# 51130  The news article is most likely referring to: ...
#
#                                            options_given  \
# 0      1. Zacatecas, state of Mexico \n2. Zacatecas, ...
# 1      1. Culiacán, capital and largest city in the M...
# 2      1. Government Palace, seat of the executive br...
# 3      1. state, organised community living under a s...
# 4      1. Fresnillo, city in Fresnillo Municipality, ...
# ...                                                  ...
# 51126  1. Mexico, country in North America \n2. Mexic...
# 51127  1. Santiago, capital city of Chile \n2. St. Ja...
# 51128  1. Enrique Peña Nieto, 64th President of Mexic...
# 51129  1. Pemex, Mexican state-owned petroleum compan...
# 51130  1. Toluca, City in the capital municipality of...
#
#                                               content_en  \
# 0      The National Energy Control Center (Cenace) an...
# 1      Culiacán, Sin.- In the esplanade of Palacio de...
# 2      Culiacán, Sin.- In the esplanade of Palacio de...
# 3      Culiacán, Sin.- In the esplanade of Palacio de...
# 4      Fresnillo, Zacatecas.- President Andrés Manuel...
# ...                                                  ...
# 51126  Santiago Nieto, the head of the Financial Inte...
# 51127  Santiago Nieto, the head of the Financial Inte...
# 51128  Santiago Nieto, the head of the Financial Inte...
# 51129  Due to the possible existence of anti-competit...
# 51130  Toluca, Méx.- The president of the PRI's State...
#
#                                       label_desc_options  \
# 0      [Zacatecas, state of Mexico, Zacatecas, city i...
# 1      [Culiacán, capital and largest city in the Mex...
# 2      [Government Palace, seat of the executive bran...
# 3      [state, organised community living under a sys...
# 4      [Fresnillo, city in Fresnillo Municipality, Za...
# ...                                                  ...
# 51126  [Mexico, country in North America, Mexico City...
# 51127  [Santiago, capital city of Chile, St. James th...
# 51128  [Enrique Peña Nieto, 64th President of Mexico,...
# 51129  [Pemex, Mexican state-owned petroleum company,...
# 51130  [Toluca, City in the capital municipality of M...
#
#                                           sents_with_ent  sents_len  \
# 0      [The blackout started at 7:58 a.m. on Monday, ...          1
# 1      [Culiacán, Sin.- In the esplanade of Palacio d...          1
# 2      [Culiacán, Sin.- In the esplanade of Palacio d...          1
# 3      [On 16 February, the Attorney General of the S...          1
# 4      [Fresnillo, Zacatecas.- President Andrés Manue...          1
# ...                                                  ...        ...
# 51126  [In an interview, Santiago Nieto explained tha...          1
# 51127  [Santiago Nieto, the head of the Financial Int...          3
# 51128  [Moreover, Nieto Said severe other officers fr...          1
# 51129  [This is a new investigation into the same pro...          1
# 51130  [Toluca, Méx.- The president of the PRI's Stat...          1
#
#                                          sb_option_given  \
# 0      Zacatecas, city in Zacatecas Municipality, Zac...
# 1      Culiacán, capital and largest city in the Mexi...
# 2      Palacio de Gobierno de Jalisco, Government bui...
# 3      state, organised community living under a syst...
# 4      Fresnillo, city in Fresnillo Municipality, Zac...
# ...                                                  ...
# 51126                   Mexico, country in North America
# 51127                          Santiago, male given name
# 51128       Enrique Peña Nieto, 64th President of Mexico
# 51129       Pemex, Mexican state-owned petroleum company
# 51130  Toluca, City in the capital municipality of Me...
#
#        index_of_option_given
# 0                          1
# 1                          0
# 2                          1
# 3                          0
# 4                          0
# ...                      ...
# 51126                      0
# 51127                      2
# 51128                      0
# 51129                      0
# 51130                      0
#
# [51131 rows x 16 columns]
